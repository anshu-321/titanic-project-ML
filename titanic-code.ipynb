# %%
import pandas as pd

# %%
train= pd.read_csv('train.csv')
test= pd.read_csv('test.csv')

train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# Data Analysis -> Filling in null vals -> Encoding -> train(sklearn)

# %%
train.shape
# train.sample(891)
# Out:
# (891, 12)

# %% [markdown]
# DATA CLEANING

# %%
train.info()
train.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# ...

# %%
train.drop(['Cabin'], axis=1, inplace=True)

# %%
train['Age'].fillna(train['Age'].mean(), inplace=True)
# Out:
# /var/folders/64/7h4nhc0j5ybbm42sh_zxgr_40000gn/T/ipykernel_47265/189249602.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Age'].fillna(train['Age'].mean(), inplace=True)

# %%
train['Embarked'].fillna(train['Embarked'].mode()[0], inplace=True)
# Out:
# /var/folders/64/7h4nhc0j5ybbm42sh_zxgr_40000gn/T/ipykernel_47265/1031565505.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Embarked'].fillna(train['Embarked'].mode()[0], inplace=True)

# %% [markdown]
# Data Analysis

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import seaborn as sns

# %%
train["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='Survived', data=train)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Sex', hue='Survived', data=train)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Embarked', hue='Survived', data=train)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# Encoding Categorical Columns

# %%
train.replace({"Sex":{"male":0,"female":1}, "Embarked":{"S":0,"C":1,"Q":2}}, inplace=True)
# Out:
# /var/folders/64/7h4nhc0j5ybbm42sh_zxgr_40000gn/T/ipykernel_47265/1546545255.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train.replace({"Sex":{"male":0,"female":1}, "Embarked":{"S":0,"C":1,"Q":2}}, inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 76.7+ KB

# %%
X = train.drop(["PassengerId","Survived","Name","Ticket"], axis=1)
Y = train["Survived"]
X.head(10)
# Out:
#    Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0       3    0  22.000000      1      0   7.2500         0
# 1       1    1  38.000000      1      0  71.2833         1
# 2       3    1  26.000000      0      0   7.9250         0
# 3       1    1  35.000000      1      0  53.1000         0
# 4       3    0  35.000000      0      0   8.0500         0
# 5       3    0  29.699118      0      0   8.4583         2
# 6       1    0  54.000000      0      0  51.8625         0
# 7       3    0   2.000000      3      1  21.0750         0
# 8       3    1  27.000000      0      2  11.1333         0
# 9       2    1  14.000000      1      0  30.0708         1

# %% [markdown]
# Model Training

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression(max_iter=1000)

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import accuracy_score

# %%
x_train_pred= model.predict(X_train)
training_data_accuracy= accuracy_score(x_train_pred, Y_train)
print("Accuracy on training data: ", training_data_accuracy)
# Out:
# Accuracy on training data:  0.8019662921348315

# %%
x_test_pred= model.predict(X_test)
test_data_accuracy = accuracy_score(x_test_pred, Y_test)
print("Accuracy on test data: ", test_data_accuracy)
# Out:
# Accuracy on test data:  0.7988826815642458

# %% [markdown]
# Training model again on the test_set

# %%
model.fit(X_test, Y_test)
# Out:
# LogisticRegression(max_iter=1000)

# %%
x_test_pred= model.predict(X_test)
test_data_accuracy = accuracy_score(x_test_pred, Y_test)
print("Accuracy on test data: ", test_data_accuracy)
# Out:
# Accuracy on test data:  0.8491620111731844

# %% [markdown]
# Comparing the results with the test data -

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test.drop(['Cabin'], axis=1, inplace=True)
test['Age'].fillna(test['Age'].mean(), inplace=True)
# Out:
# /var/folders/64/7h4nhc0j5ybbm42sh_zxgr_40000gn/T/ipykernel_47265/602873702.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['Age'].fillna(test['Age'].mean(), inplace=True)

# %%
test['Fare'].fillna(test['Fare'].mean(), inplace=True)
# Out:
# /var/folders/64/7h4nhc0j5ybbm42sh_zxgr_40000gn/T/ipykernel_47265/4105841904.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['Fare'].fillna(test['Fare'].mean(), inplace=True)

# %%
test.replace({"Sex":{"male":0,"female":1}, "Embarked":{"S":0,"C":1,"Q":2}}, inplace=True)
# Out:
# /var/folders/64/7h4nhc0j5ybbm42sh_zxgr_40000gn/T/ipykernel_47265/1166524615.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test.replace({"Sex":{"male":0,"female":1}, "Embarked":{"S":0,"C":1,"Q":2}}, inplace=True)

# %%
xt= test.drop(["PassengerId","Name","Ticket"], axis=1)

# %%
xt_test_pred= model.predict(xt)
output= pd.DataFrame({'PassengerId': test.PassengerId, 'Survived': xt_test_pred})
print(output)
# output.to_csv('submission.csv', index=False)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
output['Survived'].value_counts()
# Out:
# Survived
# 0    263
# 1    155
# Name: count, dtype: int64

# %%
sns.countplot(x='Survived', data=output)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>
